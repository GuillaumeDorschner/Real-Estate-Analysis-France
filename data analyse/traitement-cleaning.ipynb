# %% [markdown]
# # Import

# %%
#Plotly
#!pip install plotly

# %%
import pandas as pd
import numpy as np
import re
import datetime
import folium
import json
import random

# math opeations
# import math
# produce random numbers
# import random
# to load json files
import json
# datetime oprations
from datetime import timedelta
# to get web contents
from urllib.request import urlopen

# for numerical analyiss
import numpy as np
# to store and process data in dataframe
import pandas as pd

# for offline ploting
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)

# converter
# from pandas.plotting import register_matplotlib_converters
# register_matplotlib_converters()   

# hide warnings
import warnings
warnings.filterwarnings('ignore')

# to USA states details
# import us
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Extraction of data

# %%
annee = "2018"
df = pd.read_csv(f'../data/valeursfoncieres-{annee}.txt', sep = '|',decimal = ',')
df["Date mutation"] = pd.to_datetime(df["Date mutation"], format="%d/%m/%Y")
display(df)
# Out:
#          Identifiant de document  Reference document  1 Articles CGI  \
# 0                            NaN                 NaN             NaN
# 1                            NaN                 NaN             NaN
# 2                            NaN                 NaN             NaN
# 3                            NaN                 NaN             NaN
# 4                            NaN                 NaN             NaN
# ...                          ...                 ...             ...
# 3335287                      NaN                 NaN             NaN
# 3335288                      NaN                 NaN             NaN
# 3335289                      NaN                 NaN             NaN
# 3335290                      NaN                 NaN             NaN
# 3335291                      NaN                 NaN             NaN
#
#          2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0                   NaN             NaN             NaN             NaN
# 1                   NaN             NaN             NaN             NaN
# 2                   NaN             NaN             NaN             NaN
# 3                   NaN             NaN             NaN             NaN
# 4                   NaN             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 3335287             NaN             NaN             NaN             NaN
# 3335288             NaN             NaN             NaN             NaN
# 3335289             NaN             NaN             NaN             NaN
# 3335290             NaN             NaN             NaN             NaN
# 3335291             NaN             NaN             NaN             NaN
#
#          No disposition Date mutation Nature mutation  ...  \
# 0                     1    2018-01-03           Vente  ...
# 1                     1    2018-01-03           Vente  ...
# 2                     1    2018-01-04           Vente  ...
# 3                     1    2018-01-04           Vente  ...
# 4                     1    2018-01-04           Vente  ...
# ...                 ...           ...             ...  ...
# 3335287               1    2018-12-28           Vente  ...
# 3335288               1    2018-12-03           Vente  ...
# 3335289               1    2018-12-28           Vente  ...
# 3335290               1    2018-12-13    Adjudication  ...
# 3335291               1    2018-10-17           Vente  ...
#
#          Surface Carrez du 5eme lot  Nombre de lots Code type local  \
# 0                               NaN               2             2.0
# 1                               NaN               1             3.0
# 2                               NaN               0             1.0
# 3                               NaN               0             1.0
# 4                               NaN               0             1.0
# ...                             ...             ...             ...
# 3335287                         NaN               2             2.0
# 3335288                         NaN               1             2.0
# 3335289                         NaN               1             4.0
# 3335290                         NaN               2             2.0
# 3335291                         NaN               1             2.0
#
#                                        Type local Identifiant local  \
# 0                                     Appartement               NaN
# 1                                      Dépendance               NaN
# 2                                          Maison               NaN
# 3                                          Maison               NaN
# 4                                          Maison               NaN
# ...                                           ...               ...
# 3335287                               Appartement               NaN
# 3335288                               Appartement               NaN
# 3335289  Local industriel. commercial ou assimilé               NaN
# 3335290                               Appartement               NaN
# 3335291                               Appartement               NaN
#
#         Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                      73.0                        4.0            NaN
# 1                       0.0                        0.0            NaN
# 2                     163.0                        4.0              S
# 3                     163.0                        4.0             AG
# 4                      51.0                        2.0             AG
# ...                     ...                        ...            ...
# 3335287               150.0                        4.0            NaN
# 3335288                34.0                        1.0            NaN
# 3335289                60.0                        0.0            NaN
# 3335290                54.0                        2.0            NaN
# 3335291                11.0                        1.0            NaN
#
#         Nature culture speciale  Surface terrain
# 0                           NaN              NaN
# 1                           NaN              NaN
# 2                           NaN            949.0
# 3                          JARD            420.0
# 4                          JARD            420.0
# ...                         ...              ...
# 3335287                     NaN              NaN
# 3335288                     NaN              NaN
# 3335289                     NaN              NaN
# 3335290                     NaN              NaN
# 3335291                     NaN              NaN
#
# [3335292 rows x 43 columns]

# %%
data = df.copy()

# %%
'''
f = open('./valeursfoncieres-2022.txt', 'r')
file_contents = f.read()

file_contents = file_contents.replace('\n','|')
content = [i for i in file_contents.split('|')]
content = [np.NaN if x=='' else x for x in content]
chunk_size = 43
data = [content[i:i+chunk_size] for i in range(0, len(content), chunk_size)]
print(data[2][2])
f.close()
'''
# Out:
# "\nf = open('./valeursfoncieres-2022.txt', 'r')\nfile_contents = f.read()\n\nfile_contents = file_contents.replace('\n','|')\ncontent = [i for i in file_contents.split('|')]\ncontent = [np.NaN if x=='' else x for x in content]\nchunk_size = 43\ndata = [content[i:i+chunk_size] for i in range(0, len(content), chunk_size)]\nprint(data[2][2])\nf.close()\n"

# %% [markdown]
# ## Creation of a DataFrame

# %%
#df = pd.DataFrame(data[1::], columns=data[0])
pd.set_option('display.max_columns', None)
display(data)
# Out:
#          Identifiant de document  Reference document  1 Articles CGI  \
# 0                            NaN                 NaN             NaN
# 1                            NaN                 NaN             NaN
# 2                            NaN                 NaN             NaN
# 3                            NaN                 NaN             NaN
# 4                            NaN                 NaN             NaN
# ...                          ...                 ...             ...
# 3335287                      NaN                 NaN             NaN
# 3335288                      NaN                 NaN             NaN
# 3335289                      NaN                 NaN             NaN
# 3335290                      NaN                 NaN             NaN
# 3335291                      NaN                 NaN             NaN
#
#          2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0                   NaN             NaN             NaN             NaN
# 1                   NaN             NaN             NaN             NaN
# 2                   NaN             NaN             NaN             NaN
# 3                   NaN             NaN             NaN             NaN
# 4                   NaN             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 3335287             NaN             NaN             NaN             NaN
# 3335288             NaN             NaN             NaN             NaN
# 3335289             NaN             NaN             NaN             NaN
# 3335290             NaN             NaN             NaN             NaN
# 3335291             NaN             NaN             NaN             NaN
#
#          No disposition Date mutation Nature mutation  Valeur fonciere  \
# 0                     1    2018-01-03           Vente         109000.0
# 1                     1    2018-01-03           Vente         109000.0
# 2                     1    2018-01-04           Vente         239300.0
# 3                     1    2018-01-04           Vente         239300.0
# 4                     1    2018-01-04           Vente         239300.0
# ...                 ...           ...             ...              ...
# 3335287               1    2018-12-28           Vente        1192307.0
# 3335288               1    2018-12-03           Vente         383000.0
# 3335289               1    2018-12-28           Vente         746000.0
# 3335290               1    2018-12-13    Adjudication         645000.0
# 3335291               1    2018-10-17           Vente          45000.0
#
#          No voie B/T/Q Type de voie Code voie                   Voie  \
# 0           13.0   NaN          RUE      1660            GEN LOGEROT
# 1           13.0   NaN          RUE      1660            GEN LOGEROT
# 2            4.0   NaN          RUE      0025         DE LA BARMETTE
# 3            4.0   NaN          RUE      0025         DE LA BARMETTE
# 4            4.0   NaN          RUE      0025         DE LA BARMETTE
# ...          ...   ...          ...       ...                    ...
# 3335287      1.0   NaN          PAS      2012               CHOISEUL
# 3335288     12.0   NaN          RUE      7561           POISSONNIERE
# 3335289     18.0   NaN          RUE      8548  STE CROIX BRETONNERIE
# 3335290      9.0   NaN           BD      6559                MORLAND
# 3335291    273.0   NaN          RUE      8525            SAINT-DENIS
#
#          Code postal           Commune Code departement  Code commune  \
# 0             1000.0   BOURG-EN-BRESSE                1            53
# 1             1000.0   BOURG-EN-BRESSE                1            53
# 2             1250.0  NIVIGNE ET SURAN                1            95
# 3             1250.0  NIVIGNE ET SURAN                1            95
# 4             1250.0  NIVIGNE ET SURAN                1            95
# ...              ...               ...              ...           ...
# 3335287      75002.0          PARIS 02               75           102
# 3335288      75002.0          PARIS 02               75           102
# 3335289      75004.0          PARIS 04               75           104
# 3335290      75004.0          PARIS 04               75           104
# 3335291      75002.0          PARIS 02               75           102
#
#          Prefixe de section Section  No plan No Volume 1er lot  \
# 0                       NaN      AN       73       NaN       1
# 1                       NaN      AN       73       NaN      13
# 2                       NaN      AH      186       NaN     NaN
# 3                       NaN      AH      186       NaN     NaN
# 4                       NaN      AH      186       NaN     NaN
# ...                     ...     ...      ...       ...     ...
# 3335287                 NaN      AD      118       NaN    43.0
# 3335288                 NaN      AO       85       NaN     9.0
# 3335289                 NaN      AH       53       NaN     8.0
# 3335290                 NaN      AS       74       NaN   101.0
# 3335291                 NaN      AP      117       NaN    57.0
#
#          Surface Carrez du 1er lot 2eme lot  Surface Carrez du 2eme lot  \
# 0                              NaN     31.0                         NaN
# 1                              NaN      NaN                         NaN
# 2                              NaN      NaN                         NaN
# 3                              NaN      NaN                         NaN
# 4                              NaN      NaN                         NaN
# ...                            ...      ...                         ...
# 3335287                     120.54     44.0                         NaN
# 3335288                      34.78      NaN                         NaN
# 3335289                      63.46      NaN                         NaN
# 3335290                        NaN    122.0                         NaN
# 3335291                        NaN      NaN                         NaN
#
#         3eme lot  Surface Carrez du 3eme lot  4eme lot  \
# 0            NaN                         NaN       NaN
# 1            NaN                         NaN       NaN
# 2            NaN                         NaN       NaN
# 3            NaN                         NaN       NaN
# 4            NaN                         NaN       NaN
# ...          ...                         ...       ...
# 3335287      NaN                         NaN       NaN
# 3335288      NaN                         NaN       NaN
# 3335289      NaN                         NaN       NaN
# 3335290      NaN                         NaN       NaN
# 3335291      NaN                         NaN       NaN
#
#          Surface Carrez du 4eme lot 5eme lot  Surface Carrez du 5eme lot  \
# 0                               NaN      NaN                         NaN
# 1                               NaN      NaN                         NaN
# 2                               NaN      NaN                         NaN
# 3                               NaN      NaN                         NaN
# 4                               NaN      NaN                         NaN
# ...                             ...      ...                         ...
# 3335287                         NaN      NaN                         NaN
# 3335288                         NaN      NaN                         NaN
# 3335289                         NaN      NaN                         NaN
# 3335290                         NaN      NaN                         NaN
# 3335291                         NaN      NaN                         NaN
#
#          Nombre de lots  Code type local  \
# 0                     2              2.0
# 1                     1              3.0
# 2                     0              1.0
# 3                     0              1.0
# 4                     0              1.0
# ...                 ...              ...
# 3335287               2              2.0
# 3335288               1              2.0
# 3335289               1              4.0
# 3335290               2              2.0
# 3335291               1              2.0
#
#                                        Type local  Identifiant local  \
# 0                                     Appartement                NaN
# 1                                      Dépendance                NaN
# 2                                          Maison                NaN
# 3                                          Maison                NaN
# 4                                          Maison                NaN
# ...                                           ...                ...
# 3335287                               Appartement                NaN
# 3335288                               Appartement                NaN
# 3335289  Local industriel. commercial ou assimilé                NaN
# 3335290                               Appartement                NaN
# 3335291                               Appartement                NaN
#
#          Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                       73.0                        4.0            NaN
# 1                        0.0                        0.0            NaN
# 2                      163.0                        4.0              S
# 3                      163.0                        4.0             AG
# 4                       51.0                        2.0             AG
# ...                      ...                        ...            ...
# 3335287                150.0                        4.0            NaN
# 3335288                 34.0                        1.0            NaN
# 3335289                 60.0                        0.0            NaN
# 3335290                 54.0                        2.0            NaN
# 3335291                 11.0                        1.0            NaN
#
#         Nature culture speciale  Surface terrain
# 0                           NaN              NaN
# 1                           NaN              NaN
# 2                           NaN            949.0
# 3                          JARD            420.0
# 4                          JARD            420.0
# ...                         ...              ...
# 3335287                     NaN              NaN
# 3335288                     NaN              NaN
# 3335289                     NaN              NaN
# 3335290                     NaN              NaN
# 3335291                     NaN              NaN
#
# [3335292 rows x 43 columns]

# %% [markdown]
# ## Cleaning of data

# %%
columns = data.columns
drop_columns =  [columns[0],columns[1],columns[2],columns[3],columns[4],columns[5],columns[6],columns[7],columns[9],columns[12],columns[17],columns[20],columns[23],columns[26],columns[27],columns[28],columns[29],columns[30],columns[31],columns[32],columns[33],columns[37],columns[41]]
data.drop(columns = drop_columns, inplace=True, axis=1)
display(data)

print(drop_columns)
# Out:
#         Date mutation  Valeur fonciere  No voie Type de voie Code voie  \
# 0          2018-01-03         109000.0     13.0          RUE      1660
# 1          2018-01-03         109000.0     13.0          RUE      1660
# 2          2018-01-04         239300.0      4.0          RUE      0025
# 3          2018-01-04         239300.0      4.0          RUE      0025
# 4          2018-01-04         239300.0      4.0          RUE      0025
# ...               ...              ...      ...          ...       ...
# 3335287    2018-12-28        1192307.0      1.0          PAS      2012
# 3335288    2018-12-03         383000.0     12.0          RUE      7561
# 3335289    2018-12-28         746000.0     18.0          RUE      8548
# 3335290    2018-12-13         645000.0      9.0           BD      6559
# 3335291    2018-10-17          45000.0    273.0          RUE      8525
#
#                           Voie  Code postal Code departement  Code commune  \
# 0                  GEN LOGEROT       1000.0                1            53
# 1                  GEN LOGEROT       1000.0                1            53
# 2               DE LA BARMETTE       1250.0                1            95
# 3               DE LA BARMETTE       1250.0                1            95
# 4               DE LA BARMETTE       1250.0                1            95
# ...                        ...          ...              ...           ...
# 3335287               CHOISEUL      75002.0               75           102
# 3335288           POISSONNIERE      75002.0               75           102
# 3335289  STE CROIX BRETONNERIE      75004.0               75           104
# 3335290                MORLAND      75004.0               75           104
# 3335291            SAINT-DENIS      75002.0               75           102
#
#         Section  No plan 1er lot  Surface Carrez du 1er lot  Nombre de lots  \
# 0            AN       73       1                        NaN               2
# 1            AN       73      13                        NaN               1
# 2            AH      186     NaN                        NaN               0
# 3            AH      186     NaN                        NaN               0
# 4            AH      186     NaN                        NaN               0
# ...         ...      ...     ...                        ...             ...
# 3335287      AD      118    43.0                     120.54               2
# 3335288      AO       85     9.0                      34.78               1
# 3335289      AH       53     8.0                      63.46               1
# 3335290      AS       74   101.0                        NaN               2
# 3335291      AP      117    57.0                        NaN               1
#
#          Code type local                                Type local  \
# 0                    2.0                               Appartement
# 1                    3.0                                Dépendance
# 2                    1.0                                    Maison
# 3                    1.0                                    Maison
# 4                    1.0                                    Maison
# ...                  ...                                       ...
# 3335287              2.0                               Appartement
# 3335288              2.0                               Appartement
# 3335289              4.0  Local industriel. commercial ou assimilé
# 3335290              2.0                               Appartement
# 3335291              2.0                               Appartement
#
#          Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                       73.0                        4.0            NaN
# 1                        0.0                        0.0            NaN
# 2                      163.0                        4.0              S
# 3                      163.0                        4.0             AG
# 4                       51.0                        2.0             AG
# ...                      ...                        ...            ...
# 3335287                150.0                        4.0            NaN
# 3335288                 34.0                        1.0            NaN
# 3335289                 60.0                        0.0            NaN
# 3335290                 54.0                        2.0            NaN
# 3335291                 11.0                        1.0            NaN
#
#          Surface terrain
# 0                    NaN
# 1                    NaN
# 2                  949.0
# 3                  420.0
# 4                  420.0
# ...                  ...
# 3335287              NaN
# 3335288              NaN
# 3335289              NaN
# 3335290              NaN
# 3335291              NaN
#
# [3335292 rows x 20 columns]
# ['Identifiant de document', 'Reference document', '1 Articles CGI', '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI', 'No disposition', 'Nature mutation', 'B/T/Q', 'Commune', 'Prefixe de section', 'No Volume', '2eme lot', 'Surface Carrez du 2eme lot', '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot', 'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot', 'Identifiant local', 'Nature culture speciale']

# %%
data.dtypes
# Out:
# Date mutation                datetime64[ns]
# Valeur fonciere                     float64
# No voie                             float64
# Type de voie                         object
# Code voie                            object
# Voie                                 object
# Code postal                         float64
# Code departement                     object
# Code commune                          int64
# Section                              object
# No plan                               int64
# 1er lot                              object
# Surface Carrez du 1er lot           float64
# Nombre de lots                        int64
# Code type local                     float64
# Type local                           object
# Surface reelle bati                 float64
# Nombre pieces principales           float64
# Nature culture                       object
# Surface terrain                     float64
# dtype: object

# %%
#data["Surface terrain"] = data["Surface terrain"].fillna(data["Surface terrain"].median())
display(data)
# Out:
#         Date mutation  Valeur fonciere  No voie Type de voie Code voie  \
# 0          2018-01-03         109000.0     13.0          RUE      1660
# 1          2018-01-03         109000.0     13.0          RUE      1660
# 2          2018-01-04         239300.0      4.0          RUE      0025
# 3          2018-01-04         239300.0      4.0          RUE      0025
# 4          2018-01-04         239300.0      4.0          RUE      0025
# ...               ...              ...      ...          ...       ...
# 3335287    2018-12-28        1192307.0      1.0          PAS      2012
# 3335288    2018-12-03         383000.0     12.0          RUE      7561
# 3335289    2018-12-28         746000.0     18.0          RUE      8548
# 3335290    2018-12-13         645000.0      9.0           BD      6559
# 3335291    2018-10-17          45000.0    273.0          RUE      8525
#
#                           Voie  Code postal Code departement  Code commune  \
# 0                  GEN LOGEROT       1000.0                1            53
# 1                  GEN LOGEROT       1000.0                1            53
# 2               DE LA BARMETTE       1250.0                1            95
# 3               DE LA BARMETTE       1250.0                1            95
# 4               DE LA BARMETTE       1250.0                1            95
# ...                        ...          ...              ...           ...
# 3335287               CHOISEUL      75002.0               75           102
# 3335288           POISSONNIERE      75002.0               75           102
# 3335289  STE CROIX BRETONNERIE      75004.0               75           104
# 3335290                MORLAND      75004.0               75           104
# 3335291            SAINT-DENIS      75002.0               75           102
#
#         Section  No plan 1er lot  Surface Carrez du 1er lot  Nombre de lots  \
# 0            AN       73       1                        NaN               2
# 1            AN       73      13                        NaN               1
# 2            AH      186     NaN                        NaN               0
# 3            AH      186     NaN                        NaN               0
# 4            AH      186     NaN                        NaN               0
# ...         ...      ...     ...                        ...             ...
# 3335287      AD      118    43.0                     120.54               2
# 3335288      AO       85     9.0                      34.78               1
# 3335289      AH       53     8.0                      63.46               1
# 3335290      AS       74   101.0                        NaN               2
# 3335291      AP      117    57.0                        NaN               1
#
#          Code type local                                Type local  \
# 0                    2.0                               Appartement
# 1                    3.0                                Dépendance
# 2                    1.0                                    Maison
# 3                    1.0                                    Maison
# 4                    1.0                                    Maison
# ...                  ...                                       ...
# 3335287              2.0                               Appartement
# 3335288              2.0                               Appartement
# 3335289              4.0  Local industriel. commercial ou assimilé
# 3335290              2.0                               Appartement
# 3335291              2.0                               Appartement
#
#          Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                       73.0                        4.0            NaN
# 1                        0.0                        0.0            NaN
# 2                      163.0                        4.0              S
# 3                      163.0                        4.0             AG
# 4                       51.0                        2.0             AG
# ...                      ...                        ...            ...
# 3335287                150.0                        4.0            NaN
# 3335288                 34.0                        1.0            NaN
# 3335289                 60.0                        0.0            NaN
# 3335290                 54.0                        2.0            NaN
# 3335291                 11.0                        1.0            NaN
#
#          Surface terrain
# 0                    NaN
# 1                    NaN
# 2                  949.0
# 3                  420.0
# 4                  420.0
# ...                  ...
# 3335287              NaN
# 3335288              NaN
# 3335289              NaN
# 3335290              NaN
# 3335291              NaN
#
# [3335292 rows x 20 columns]

# %%
#df_prix_moy_m2_dep  = data[data['Surface reelle bati'].notnull()]
#df_prix_moy_m2_dep = df_prix_moy_m2_dep.reset_index(drop = True)
#display(df_prix_moy_m2_dep)
paris = data[(data["Code departement"] == 75) & (data["Type local"] != "Dépendance") & (data["Type local"] != "Local industriel. commercial ou assimilé")].reset_index(drop = True)
paris["Prix mètre carré"] = paris["Valeur fonciere"]/paris["Surface reelle bati"]
display(paris)
# Out:
#       Date mutation  Valeur fonciere  No voie Type de voie Code voie  \
# 0        2018-01-04        1202000.0     10.0           AV      7250
# 1        2018-01-09         130000.0     20.0          RUE      8520
# 2        2018-01-03          15000.0     12.0          RUE      9905
# 3        2018-01-03         650000.0    174.0           BD      4485
# 4        2018-01-05           3000.0    187.0          RUE      3518
# ...             ...              ...      ...          ...       ...
# 44027    2018-12-26         220000.0     14.0          RUE      5702
# 44028    2018-12-28        1192307.0      1.0          PAS      2012
# 44029    2018-12-03         383000.0     12.0          RUE      7561
# 44030    2018-12-13         645000.0      9.0           BD      6559
# 44031    2018-10-17          45000.0    273.0          RUE      8525
#
#                            Voie  Code postal Code departement  Code commune  \
# 0                       PERCIER      75008.0               75           108
# 1                  SAINT CLAUDE      75003.0               75           103
# 2                         VOLTA      75003.0               75           103
# 3                     HAUSSMANN      75008.0               75           108
# 4      DU FAUBOURG SAINT HONORE      75008.0               75           108
# ...                         ...          ...              ...           ...
# 44027      DES LIONS SAINT PAUL      75004.0               75           104
# 44028                  CHOISEUL      75002.0               75           102
# 44029              POISSONNIERE      75002.0               75           102
# 44030                   MORLAND      75004.0               75           104
# 44031               SAINT-DENIS      75002.0               75           102
#
#       Section  No plan 1er lot  Surface Carrez du 1er lot  Nombre de lots  \
# 0          CJ        3    77.0                     159.20               3
# 1          AL       72   206.0                        NaN               4
# 2          AE      136     7.0                       8.30               1
# 3          BD       36    59.0                      96.58               2
# 4          AW       27    37.0                        NaN               1
# ...       ...      ...     ...                        ...             ...
# 44027      AQ      127   126.0                        NaN               2
# 44028      AD      118    43.0                     120.54               2
# 44029      AO       85     9.0                      34.78               1
# 44030      AS       74   101.0                        NaN               2
# 44031      AP      117    57.0                        NaN               1
#
#        Code type local   Type local  Surface reelle bati  \
# 0                  2.0  Appartement                120.0
# 1                  2.0  Appartement                 22.0
# 2                  2.0  Appartement                  9.0
# 3                  2.0  Appartement                 96.0
# 4                  2.0  Appartement                 58.0
# ...                ...          ...                  ...
# 44027              2.0  Appartement                 29.0
# 44028              2.0  Appartement                150.0
# 44029              2.0  Appartement                 34.0
# 44030              2.0  Appartement                 54.0
# 44031              2.0  Appartement                 11.0
#
#        Nombre pieces principales Nature culture  Surface terrain  \
# 0                            2.0            NaN              NaN
# 1                            1.0            NaN              NaN
# 2                            1.0            NaN              NaN
# 3                            3.0            NaN              NaN
# 4                            3.0            NaN              NaN
# ...                          ...            ...              ...
# 44027                        1.0            NaN              NaN
# 44028                        4.0            NaN              NaN
# 44029                        1.0            NaN              NaN
# 44030                        2.0            NaN              NaN
# 44031                        1.0            NaN              NaN
#
#        Prix mètre carré
# 0          10016.666667
# 1           5909.090909
# 2           1666.666667
# 3           6770.833333
# 4             51.724138
# ...                 ...
# 44027       7586.206897
# 44028       7948.713333
# 44029      11264.705882
# 44030      11944.444444
# 44031       4090.909091
#
# [44032 rows x 21 columns]

# %%
erreur = data[(data["Valeur fonciere"] <= 100000000)&(data["Type local"].notnull())]
paris = erreur[(erreur["Code departement"] == 75)]
