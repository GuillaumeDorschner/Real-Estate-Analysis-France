# %% [markdown]
# # Import

# %%
#Plotly
#pip install plotly

# %%
import pandas as pd
import numpy as np
import re
import datetime

# math opeations
# import math
# produce random numbers
# import random
# to load json files
import json
# datetime oprations
from datetime import timedelta
# to get web contents
from urllib.request import urlopen

# for numerical analyiss
import numpy as np
# to store and process data in dataframe
import pandas as pd

# for offline ploting
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)

# converter
# from pandas.plotting import register_matplotlib_converters
# register_matplotlib_converters()   

# hide warnings
import warnings
warnings.filterwarnings('ignore')

# to USA states details
# import us
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Extraction of data

# %%
df = pd.read_csv(r'Analyse-Fonciere/Data/valeursfoncieres-2022.txt', sep = '|',decimal = ',')
df["Date mutation"] = pd.to_datetime(df["Date mutation"], format="%d/%m/%Y")
display(df)
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_21260\2800937360.py:1: DtypeWarning: Columns (18,23,24,26,28,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'Analyse-Fonciere/Data/valeursfoncieres-2022.txt', sep = '|',decimal = ',')
#          Identifiant de document  Reference document  1 Articles CGI  \
# 0                            NaN                 NaN             NaN
# 1                            NaN                 NaN             NaN
# 2                            NaN                 NaN             NaN
# 3                            NaN                 NaN             NaN
# 4                            NaN                 NaN             NaN
# ...                          ...                 ...             ...
# 3803880                      NaN                 NaN             NaN
# 3803881                      NaN                 NaN             NaN
# 3803882                      NaN                 NaN             NaN
# 3803883                      NaN                 NaN             NaN
# 3803884                      NaN                 NaN             NaN
#
#          2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0                   NaN             NaN             NaN             NaN
# 1                   NaN             NaN             NaN             NaN
# 2                   NaN             NaN             NaN             NaN
# 3                   NaN             NaN             NaN             NaN
# 4                   NaN             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 3803880             NaN             NaN             NaN             NaN
# 3803881             NaN             NaN             NaN             NaN
# 3803882             NaN             NaN             NaN             NaN
# 3803883             NaN             NaN             NaN             NaN
# 3803884             NaN             NaN             NaN             NaN
#
#          No disposition Date mutation Nature mutation  Valeur fonciere  \
# 0                     1    2022-01-03           Vente          55000.0
# 1                     1    2022-01-03           Vente         143000.0
# 2                     1    2022-01-03           Vente         143000.0
# 3                     1    2022-01-03           Vente         143000.0
# 4                     1    2022-01-04           Vente            300.0
# ...                 ...           ...             ...              ...
# 3803880               1    2022-12-30           Vente        3500000.0
# 3803881               1    2022-12-19           Vente         525000.0
# 3803882               1    2022-12-19           Vente         525000.0
# 3803883               1    2022-12-30           Vente          15500.0
# 3803884               1    2022-11-21           Vente          30000.0
#
#          No voie B/T/Q Type de voie Code voie               Voie  Code postal  \
# 0           13.0   NaN          RUE      2280      DE LA LIBERTE       1000.0
# 1            NaN   NaN          NaN      B010       CHAMP COCHET       1480.0
# 2            NaN   NaN          NaN      B010       CHAMP COCHET       1480.0
# 3           98.0   NaN          RTE      0055       DE LA DOMBES       1480.0
# 4            NaN   NaN          NaN      B031        AUX PIERRES       1480.0
# ...          ...   ...          ...       ...                ...          ...
# 3803880     19.0   NaN          RUE      4879        JEAN DOLENT      75014.0
# 3803881      3.0   NaN          RUE      3842  FREDERIC MAGISSON      75015.0
# 3803882      3.0   NaN          RUE      3842  FREDERIC MAGISSON      75015.0
# 3803883     69.0   NaN          RUE      0679           BARRAULT      75013.0
# 3803884     48.0   NaN          RUE      8358     DE LA ROQUETTE      75011.0
#
#                    Commune Code departement  Code commune  Prefixe de section  \
# 0          BOURG-EN-BRESSE                1            53                 NaN
# 1                SAVIGNEUX                1           398                 NaN
# 2                SAVIGNEUX                1           398                 NaN
# 3                SAVIGNEUX                1           398                 NaN
# 4        MESSIMY SUR SAONE                1           243                 NaN
# ...                    ...              ...           ...                 ...
# 3803880           PARIS 14               75           114                 NaN
# 3803881           PARIS 15               75           115                 NaN
# 3803882           PARIS 15               75           115                 NaN
# 3803883           PARIS 13               75           113                 NaN
# 3803884           PARIS 11               75           111                 NaN
#
#         Section  No plan No Volume 1er lot  Surface Carrez du 1er lot  \
# 0            AM      102       NaN     7.0                      24.10
# 1            ZE      184       NaN     NaN                        NaN
# 2            ZE      185       NaN     NaN                        NaN
# 3            ZE      187       NaN     1.0                     123.23
# 4             A      643       NaN     NaN                        NaN
# ...         ...      ...       ...     ...                        ...
# 3803880      AS       41       NaN       3                        NaN
# 3803881      EJ       51       NaN      49                      46.65
# 3803882      EJ       51       NaN      49                      46.65
# 3803883      DM       28       NaN     244                        NaN
# 3803884      CD       88       NaN     516                        NaN
#
#         2eme lot  Surface Carrez du 2eme lot 3eme lot  \
# 0            NaN                         NaN      NaN
# 1            NaN                         NaN      NaN
# 2            NaN                         NaN      NaN
# 3            NaN                         NaN      NaN
# 4            NaN                         NaN      NaN
# ...          ...                         ...      ...
# 3803880      NaN                         NaN      NaN
# 3803881     50.0                         NaN      NaN
# 3803882     50.0                         NaN      NaN
# 3803883      NaN                         NaN      NaN
# 3803884      NaN                         NaN      NaN
#
#          Surface Carrez du 3eme lot  4eme lot  Surface Carrez du 4eme lot  \
# 0                               NaN       NaN                         NaN
# 1                               NaN       NaN                         NaN
# 2                               NaN       NaN                         NaN
# 3                               NaN       NaN                         NaN
# 4                               NaN       NaN                         NaN
# ...                             ...       ...                         ...
# 3803880                         NaN       NaN                         NaN
# 3803881                         NaN       NaN                         NaN
# 3803882                         NaN       NaN                         NaN
# 3803883                         NaN       NaN                         NaN
# 3803884                         NaN       NaN                         NaN
#
#          5eme lot  Surface Carrez du 5eme lot  Nombre de lots  \
# 0             NaN                         NaN               1
# 1             NaN                         NaN               0
# 2             NaN                         NaN               0
# 3             NaN                         NaN               1
# 4             NaN                         NaN               0
# ...           ...                         ...             ...
# 3803880       NaN                         NaN               1
# 3803881       NaN                         NaN               2
# 3803882       NaN                         NaN               2
# 3803883       NaN                         NaN               1
# 3803884       NaN                         NaN               1
#
#          Code type local                                Type local  \
# 0                    2.0                               Appartement
# 1                    NaN                                       NaN
# 2                    NaN                                       NaN
# 3                    2.0                               Appartement
# 4                    NaN                                       NaN
# ...                  ...                                       ...
# 3803880              4.0  Local industriel. commercial ou assimilé
# 3803881              3.0                                Dépendance
# 3803882              2.0                               Appartement
# 3803883              3.0                                Dépendance
# 3803884              3.0                                Dépendance
#
#          Identifiant local  Surface reelle bati  Nombre pieces principales  \
# 0                      NaN                 24.0                        1.0
# 1                      NaN                  NaN                        NaN
# 2                      NaN                  NaN                        NaN
# 3                      NaN                140.0                        3.0
# 4                      NaN                  NaN                        NaN
# ...                    ...                  ...                        ...
# 3803880                NaN                327.0                        0.0
# 3803881                NaN                  0.0                        0.0
# 3803882                NaN                 40.0                        3.0
# 3803883                NaN                  0.0                        0.0
# 3803884                NaN                  0.0                        0.0
#
#         Nature culture Nature culture speciale  Surface terrain
# 0                  NaN                     NaN              NaN
# 1                    S                     NaN             84.0
# 2                    S                     NaN             88.0
# 3                  NaN                     NaN              NaN
# 4                    T                     NaN            510.0
# ...                ...                     ...              ...
# 3803880            NaN                     NaN              NaN
# 3803881            NaN                     NaN              NaN
# 3803882            NaN                     NaN              NaN
# 3803883            NaN                     NaN              NaN
# 3803884            NaN                     NaN              NaN
#
# [3803885 rows x 43 columns]

# %%
data = df

# %%
'''
f = open('./valeursfoncieres-2022.txt', 'r')
file_contents = f.read()

file_contents = file_contents.replace('\n','|')
content = [i for i in file_contents.split('|')]
content = [np.NaN if x=='' else x for x in content]
chunk_size = 43
data = [content[i:i+chunk_size] for i in range(0, len(content), chunk_size)]
print(data[2][2])
f.close()
'''
# Out:
# "\nf = open('./valeursfoncieres-2022.txt', 'r')\nfile_contents = f.read()\n\nfile_contents = file_contents.replace('\n','|')\ncontent = [i for i in file_contents.split('|')]\ncontent = [np.NaN if x=='' else x for x in content]\nchunk_size = 43\ndata = [content[i:i+chunk_size] for i in range(0, len(content), chunk_size)]\nprint(data[2][2])\nf.close()\n"

# %% [markdown]
# ## Creation of a DataFrame

# %%
#df = pd.DataFrame(data[1::], columns=data[0])
pd.set_option('display.max_columns', None)
display(data)
# Out:
#          Identifiant de document  Reference document  1 Articles CGI  \
# 0                            NaN                 NaN             NaN
# 1                            NaN                 NaN             NaN
# 2                            NaN                 NaN             NaN
# 3                            NaN                 NaN             NaN
# 4                            NaN                 NaN             NaN
# ...                          ...                 ...             ...
# 3803880                      NaN                 NaN             NaN
# 3803881                      NaN                 NaN             NaN
# 3803882                      NaN                 NaN             NaN
# 3803883                      NaN                 NaN             NaN
# 3803884                      NaN                 NaN             NaN
#
#          2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0                   NaN             NaN             NaN             NaN
# 1                   NaN             NaN             NaN             NaN
# 2                   NaN             NaN             NaN             NaN
# 3                   NaN             NaN             NaN             NaN
# 4                   NaN             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 3803880             NaN             NaN             NaN             NaN
# 3803881             NaN             NaN             NaN             NaN
# 3803882             NaN             NaN             NaN             NaN
# 3803883             NaN             NaN             NaN             NaN
# 3803884             NaN             NaN             NaN             NaN
#
#          No disposition Date mutation Nature mutation  Valeur fonciere  \
# 0                     1    2022-01-03           Vente          55000.0
# 1                     1    2022-01-03           Vente         143000.0
# 2                     1    2022-01-03           Vente         143000.0
# 3                     1    2022-01-03           Vente         143000.0
# 4                     1    2022-01-04           Vente            300.0
# ...                 ...           ...             ...              ...
# 3803880               1    2022-12-30           Vente        3500000.0
# 3803881               1    2022-12-19           Vente         525000.0
# 3803882               1    2022-12-19           Vente         525000.0
# 3803883               1    2022-12-30           Vente          15500.0
# 3803884               1    2022-11-21           Vente          30000.0
#
#          No voie B/T/Q Type de voie Code voie               Voie  Code postal  \
# 0           13.0   NaN          RUE      2280      DE LA LIBERTE       1000.0
# 1            NaN   NaN          NaN      B010       CHAMP COCHET       1480.0
# 2            NaN   NaN          NaN      B010       CHAMP COCHET       1480.0
# 3           98.0   NaN          RTE      0055       DE LA DOMBES       1480.0
# 4            NaN   NaN          NaN      B031        AUX PIERRES       1480.0
# ...          ...   ...          ...       ...                ...          ...
# 3803880     19.0   NaN          RUE      4879        JEAN DOLENT      75014.0
# 3803881      3.0   NaN          RUE      3842  FREDERIC MAGISSON      75015.0
# 3803882      3.0   NaN          RUE      3842  FREDERIC MAGISSON      75015.0
# 3803883     69.0   NaN          RUE      0679           BARRAULT      75013.0
# 3803884     48.0   NaN          RUE      8358     DE LA ROQUETTE      75011.0
#
#                    Commune Code departement  Code commune  Prefixe de section  \
# 0          BOURG-EN-BRESSE                1            53                 NaN
# 1                SAVIGNEUX                1           398                 NaN
# 2                SAVIGNEUX                1           398                 NaN
# 3                SAVIGNEUX                1           398                 NaN
# 4        MESSIMY SUR SAONE                1           243                 NaN
# ...                    ...              ...           ...                 ...
# 3803880           PARIS 14               75           114                 NaN
# 3803881           PARIS 15               75           115                 NaN
# 3803882           PARIS 15               75           115                 NaN
# 3803883           PARIS 13               75           113                 NaN
# 3803884           PARIS 11               75           111                 NaN
#
#         Section  No plan No Volume 1er lot  Surface Carrez du 1er lot  \
# 0            AM      102       NaN     7.0                      24.10
# 1            ZE      184       NaN     NaN                        NaN
# 2            ZE      185       NaN     NaN                        NaN
# 3            ZE      187       NaN     1.0                     123.23
# 4             A      643       NaN     NaN                        NaN
# ...         ...      ...       ...     ...                        ...
# 3803880      AS       41       NaN       3                        NaN
# 3803881      EJ       51       NaN      49                      46.65
# 3803882      EJ       51       NaN      49                      46.65
# 3803883      DM       28       NaN     244                        NaN
# 3803884      CD       88       NaN     516                        NaN
#
#         2eme lot  Surface Carrez du 2eme lot 3eme lot  \
# 0            NaN                         NaN      NaN
# 1            NaN                         NaN      NaN
# 2            NaN                         NaN      NaN
# 3            NaN                         NaN      NaN
# 4            NaN                         NaN      NaN
# ...          ...                         ...      ...
# 3803880      NaN                         NaN      NaN
# 3803881     50.0                         NaN      NaN
# 3803882     50.0                         NaN      NaN
# 3803883      NaN                         NaN      NaN
# 3803884      NaN                         NaN      NaN
#
#          Surface Carrez du 3eme lot  4eme lot  Surface Carrez du 4eme lot  \
# 0                               NaN       NaN                         NaN
# 1                               NaN       NaN                         NaN
# 2                               NaN       NaN                         NaN
# 3                               NaN       NaN                         NaN
# 4                               NaN       NaN                         NaN
# ...                             ...       ...                         ...
# 3803880                         NaN       NaN                         NaN
# 3803881                         NaN       NaN                         NaN
# 3803882                         NaN       NaN                         NaN
# 3803883                         NaN       NaN                         NaN
# 3803884                         NaN       NaN                         NaN
#
#          5eme lot  Surface Carrez du 5eme lot  Nombre de lots  \
# 0             NaN                         NaN               1
# 1             NaN                         NaN               0
# 2             NaN                         NaN               0
# 3             NaN                         NaN               1
# 4             NaN                         NaN               0
# ...           ...                         ...             ...
# 3803880       NaN                         NaN               1
# 3803881       NaN                         NaN               2
# 3803882       NaN                         NaN               2
# 3803883       NaN                         NaN               1
# 3803884       NaN                         NaN               1
#
#          Code type local                                Type local  \
# 0                    2.0                               Appartement
# 1                    NaN                                       NaN
# 2                    NaN                                       NaN
# 3                    2.0                               Appartement
# 4                    NaN                                       NaN
# ...                  ...                                       ...
# 3803880              4.0  Local industriel. commercial ou assimilé
# 3803881              3.0                                Dépendance
# 3803882              2.0                               Appartement
# 3803883              3.0                                Dépendance
# 3803884              3.0                                Dépendance
#
#          Identifiant local  Surface reelle bati  Nombre pieces principales  \
# 0                      NaN                 24.0                        1.0
# 1                      NaN                  NaN                        NaN
# 2                      NaN                  NaN                        NaN
# 3                      NaN                140.0                        3.0
# 4                      NaN                  NaN                        NaN
# ...                    ...                  ...                        ...
# 3803880                NaN                327.0                        0.0
# 3803881                NaN                  0.0                        0.0
# 3803882                NaN                 40.0                        3.0
# 3803883                NaN                  0.0                        0.0
# 3803884                NaN                  0.0                        0.0
#
#         Nature culture Nature culture speciale  Surface terrain
# 0                  NaN                     NaN              NaN
# 1                    S                     NaN             84.0
# 2                    S                     NaN             88.0
# 3                  NaN                     NaN              NaN
# 4                    T                     NaN            510.0
# ...                ...                     ...              ...
# 3803880            NaN                     NaN              NaN
# 3803881            NaN                     NaN              NaN
# 3803882            NaN                     NaN              NaN
# 3803883            NaN                     NaN              NaN
# 3803884            NaN                     NaN              NaN
#
# [3803885 rows x 43 columns]

# %% [markdown]
# ## Cleaning of data

# %%
columns = data.columns
drop_columns =  [columns[0],columns[1],columns[2],columns[3],columns[4],columns[5],columns[6],columns[7],columns[9],columns[12],columns[17],columns[20],columns[23],columns[26],columns[27],columns[28],columns[29],columns[30],columns[31],columns[32],columns[33],columns[37],columns[41]]
df.drop(columns = drop_columns, inplace=True, axis=1)
display(df)

print(drop_columns)
# Out:
#         Date mutation  Valeur fonciere  No voie Type de voie Code voie  \
# 0          2022-01-03          55000.0     13.0          RUE      2280
# 1          2022-01-03         143000.0      NaN          NaN      B010
# 2          2022-01-03         143000.0      NaN          NaN      B010
# 3          2022-01-03         143000.0     98.0          RTE      0055
# 4          2022-01-04            300.0      NaN          NaN      B031
# ...               ...              ...      ...          ...       ...
# 3803880    2022-12-30        3500000.0     19.0          RUE      4879
# 3803881    2022-12-19         525000.0      3.0          RUE      3842
# 3803882    2022-12-19         525000.0      3.0          RUE      3842
# 3803883    2022-12-30          15500.0     69.0          RUE      0679
# 3803884    2022-11-21          30000.0     48.0          RUE      8358
#
#                       Voie  Code postal Code departement  Code commune  \
# 0            DE LA LIBERTE       1000.0                1            53
# 1             CHAMP COCHET       1480.0                1           398
# 2             CHAMP COCHET       1480.0                1           398
# 3             DE LA DOMBES       1480.0                1           398
# 4              AUX PIERRES       1480.0                1           243
# ...                    ...          ...              ...           ...
# 3803880        JEAN DOLENT      75014.0               75           114
# 3803881  FREDERIC MAGISSON      75015.0               75           115
# 3803882  FREDERIC MAGISSON      75015.0               75           115
# 3803883           BARRAULT      75013.0               75           113
# 3803884     DE LA ROQUETTE      75011.0               75           111
#
#         Section  No plan 1er lot  Surface Carrez du 1er lot  Nombre de lots  \
# 0            AM      102     7.0                      24.10               1
# 1            ZE      184     NaN                        NaN               0
# 2            ZE      185     NaN                        NaN               0
# 3            ZE      187     1.0                     123.23               1
# 4             A      643     NaN                        NaN               0
# ...         ...      ...     ...                        ...             ...
# 3803880      AS       41       3                        NaN               1
# 3803881      EJ       51      49                      46.65               2
# 3803882      EJ       51      49                      46.65               2
# 3803883      DM       28     244                        NaN               1
# 3803884      CD       88     516                        NaN               1
#
#          Code type local                                Type local  \
# 0                    2.0                               Appartement
# 1                    NaN                                       NaN
# 2                    NaN                                       NaN
# 3                    2.0                               Appartement
# 4                    NaN                                       NaN
# ...                  ...                                       ...
# 3803880              4.0  Local industriel. commercial ou assimilé
# 3803881              3.0                                Dépendance
# 3803882              2.0                               Appartement
# 3803883              3.0                                Dépendance
# 3803884              3.0                                Dépendance
#
#          Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                       24.0                        1.0            NaN
# 1                        NaN                        NaN              S
# 2                        NaN                        NaN              S
# 3                      140.0                        3.0            NaN
# 4                        NaN                        NaN              T
# ...                      ...                        ...            ...
# 3803880                327.0                        0.0            NaN
# 3803881                  0.0                        0.0            NaN
# 3803882                 40.0                        3.0            NaN
# 3803883                  0.0                        0.0            NaN
# 3803884                  0.0                        0.0            NaN
#
#          Surface terrain
# 0                    NaN
# 1                   84.0
# 2                   88.0
# 3                    NaN
# 4                  510.0
# ...                  ...
# 3803880              NaN
# 3803881              NaN
# 3803882              NaN
# 3803883              NaN
# 3803884              NaN
#
# [3803885 rows x 20 columns]
# ['Identifiant de document', 'Reference document', '1 Articles CGI', '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI', 'No disposition', 'Nature mutation', 'B/T/Q', 'Commune', 'Prefixe de section', 'No Volume', '2eme lot', 'Surface Carrez du 2eme lot', '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot', 'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot', 'Identifiant local', 'Nature culture speciale']

# %%
data.dtypes
# Out:
# Date mutation                datetime64[ns]
# Valeur fonciere                     float64
# No voie                             float64
# Type de voie                         object
# Code voie                            object
# Voie                                 object
# Code postal                         float64
# Code departement                     object
# Code commune                          int64
# Section                              object
# No plan                               int64
# 1er lot                              object
# Surface Carrez du 1er lot           float64
# Nombre de lots                        int64
# Code type local                     float64
# Type local                           object
# Surface reelle bati                 float64
# Nombre pieces principales           float64
# Nature culture                       object
# Surface terrain                     float64
# dtype: object

# %%
#data["Surface terrain"] = data["Surface terrain"].fillna(data["Surface terrain"].median())
display(data)
# Out:
#         Date mutation  Valeur fonciere  No voie Type de voie Code voie  \
# 0          2022-01-03          55000.0     13.0          RUE      2280
# 1          2022-01-03         143000.0      NaN          NaN      B010
# 2          2022-01-03         143000.0      NaN          NaN      B010
# 3          2022-01-03         143000.0     98.0          RTE      0055
# 4          2022-01-04            300.0      NaN          NaN      B031
# ...               ...              ...      ...          ...       ...
# 3803880    2022-12-30        3500000.0     19.0          RUE      4879
# 3803881    2022-12-19         525000.0      3.0          RUE      3842
# 3803882    2022-12-19         525000.0      3.0          RUE      3842
# 3803883    2022-12-30          15500.0     69.0          RUE      0679
# 3803884    2022-11-21          30000.0     48.0          RUE      8358
#
#                       Voie  Code postal Code departement  Code commune  \
# 0            DE LA LIBERTE       1000.0                1            53
# 1             CHAMP COCHET       1480.0                1           398
# 2             CHAMP COCHET       1480.0                1           398
# 3             DE LA DOMBES       1480.0                1           398
# 4              AUX PIERRES       1480.0                1           243
# ...                    ...          ...              ...           ...
# 3803880        JEAN DOLENT      75014.0               75           114
# 3803881  FREDERIC MAGISSON      75015.0               75           115
# 3803882  FREDERIC MAGISSON      75015.0               75           115
# 3803883           BARRAULT      75013.0               75           113
# 3803884     DE LA ROQUETTE      75011.0               75           111
#
#         Section  No plan 1er lot  Surface Carrez du 1er lot  Nombre de lots  \
# 0            AM      102     7.0                      24.10               1
# 1            ZE      184     NaN                        NaN               0
# 2            ZE      185     NaN                        NaN               0
# 3            ZE      187     1.0                     123.23               1
# 4             A      643     NaN                        NaN               0
# ...         ...      ...     ...                        ...             ...
# 3803880      AS       41       3                        NaN               1
# 3803881      EJ       51      49                      46.65               2
# 3803882      EJ       51      49                      46.65               2
# 3803883      DM       28     244                        NaN               1
# 3803884      CD       88     516                        NaN               1
#
#          Code type local                                Type local  \
# 0                    2.0                               Appartement
# 1                    NaN                                       NaN
# 2                    NaN                                       NaN
# 3                    2.0                               Appartement
# 4                    NaN                                       NaN
# ...                  ...                                       ...
# 3803880              4.0  Local industriel. commercial ou assimilé
# 3803881              3.0                                Dépendance
# 3803882              2.0                               Appartement
# 3803883              3.0                                Dépendance
# 3803884              3.0                                Dépendance
#
#          Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                       24.0                        1.0            NaN
# 1                        NaN                        NaN              S
# 2                        NaN                        NaN              S
# 3                      140.0                        3.0            NaN
# 4                        NaN                        NaN              T
# ...                      ...                        ...            ...
# 3803880                327.0                        0.0            NaN
# 3803881                  0.0                        0.0            NaN
# 3803882                 40.0                        3.0            NaN
# 3803883                  0.0                        0.0            NaN
# 3803884                  0.0                        0.0            NaN
#
#          Surface terrain
# 0                    NaN
# 1                   84.0
# 2                   88.0
# 3                    NaN
# 4                  510.0
# ...                  ...
# 3803880              NaN
# 3803881              NaN
# 3803882              NaN
# 3803883              NaN
# 3803884              NaN
#
# [3803885 rows x 20 columns]

# %%
#df_prix_moy_m2_dep  = data[data['Surface reelle bati'].notnull()]
#df_prix_moy_m2_dep = df_prix_moy_m2_dep.reset_index(drop = True)
#display(df_prix_moy_m2_dep)
paris = data[(data["Code departement"] == 75) & (data["Type local"] != "Dépendance")].reset_index(drop = True)
paris["Prix mètre carré"] = paris["Valeur fonciere"]/paris["Surface reelle bati"]
display(paris)
# Out:
#       Date mutation  Valeur fonciere  No voie Type de voie Code voie  \
# 0        2022-01-04         580000.0     13.0          RUE      9002
# 1        2022-01-04         580000.0     13.0          RUE      9002
# 2        2022-01-06         605000.0     51.0          RUE      1880
# 3        2022-01-05         716250.0      6.0          RUE      7155
# 4        2022-01-05         320000.0      4.0          RUE      1924
# ...             ...              ...      ...          ...       ...
# 51338    2022-11-03         291000.0    128.0          RUE      0012
# 51339    2022-12-23         934000.0      5.0          VLA      3488
# 51340    2022-12-23          70000.0     67.0          RUE      1255
# 51341    2022-12-30        3500000.0     19.0          RUE      4879
# 51342    2022-12-19         525000.0      3.0          RUE      3842
#
#                     Voie  Code postal Code departement  Code commune Section  \
# 0               DE SOFIA      75018.0               75           118      BR
# 1               DE SOFIA      75018.0               75           118      BR
# 2                CHARLOT      75003.0               75           103      AH
# 3          PAUL ESCUDIER      75009.0               75           109      AC
# 4      DU CHATEAU LANDON      75010.0               75           110      AG
# ...                  ...          ...              ...           ...     ...
# 51338   DE L ABBE GROULT      75015.0               75           115      AE
# 51339        FAISANDERIE      75016.0               75           116      EE
# 51340           BRANCION      75015.0               75           115      AJ
# 51341        JEAN DOLENT      75014.0               75           114      AS
# 51342  FREDERIC MAGISSON      75015.0               75           115      EJ
#
#        No plan 1er lot  Surface Carrez du 1er lot  Nombre de lots  \
# 0           26    25.0                        NaN               2
# 1           26    55.0                      61.00               3
# 2           72     7.0                      40.66               1
# 3          148    24.0                        NaN               3
# 4           47    27.0                        NaN               2
# ...        ...     ...                        ...             ...
# 51338       96      20                        NaN               1
# 51339       64       1                        NaN               2
# 51340       28     112                        NaN               2
# 51341       41       3                        NaN               1
# 51342       51      49                      46.65               2
#
#        Code type local                                Type local  \
# 0                  2.0                               Appartement
# 1                  2.0                               Appartement
# 2                  2.0                               Appartement
# 3                  2.0                               Appartement
# 4                  2.0                               Appartement
# ...                ...                                       ...
# 51338              2.0                               Appartement
# 51339              2.0                               Appartement
# 51340              2.0                               Appartement
# 51341              4.0  Local industriel. commercial ou assimilé
# 51342              2.0                               Appartement
#
#        Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                     20.0                        2.0            NaN
# 1                     25.0                        2.0            NaN
# 2                     42.0                        3.0            NaN
# 3                     69.0                        3.0            NaN
# 4                     33.0                        2.0            NaN
# ...                    ...                        ...            ...
# 51338                 35.0                        2.0            NaN
# 51339                 58.0                        2.0            NaN
# 51340                 15.0                        1.0            NaN
# 51341                327.0                        0.0            NaN
# 51342                 40.0                        3.0            NaN
#
#        Surface terrain  Prix mètre carré
# 0                  NaN      29000.000000
# 1                  NaN      23200.000000
# 2                  NaN      14404.761905
# 3                  NaN      10380.434783
# 4                  NaN       9696.969697
# ...                ...               ...
# 51338              NaN       8314.285714
# 51339              NaN      16103.448276
# 51340              NaN       4666.666667
# 51341              NaN      10703.363914
# 51342              NaN      13125.000000
#
# [51343 rows x 21 columns]

# %%
def plot_map(df, col, pal):
    df = df[df[col]>0]
    fig = px.choropleth(df, locations="Code postal", locationmode='country names', 
                  color=col, hover_name="Code postal", 
                  title=col, hover_data=[col], color_continuous_scale=pal)
#     fig.update_layout(coloraxis_showscale=False)
    fig.show()

# %%
plot_map(data, 'Confirmed', 'matter')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plot_map(country_wise, 'Confirmed', 'matter')
#
# NameError: name 'country_wise' is not defined
